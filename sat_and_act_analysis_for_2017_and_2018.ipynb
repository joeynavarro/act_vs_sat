# %% [markdown]
# # SAT & ACT Analysis for 2017 & 2018

# %%
#library imports
import pandas as pd
import numpy as np
from IPython.display import Image
Image(filename = 'test_taker.jpg')
#Photo by [Green Chameleon](https://unsplash.com/@craftedbygc?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText) on [Unsplash](https://unsplash.com/s/photos/students-testing?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText)

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Participation rate changes have been recorded for both the SAT and ACT exams between 2017 and 2018. This report explores the reasons for the these changes within the United States categorized by test and subject.

# %% [markdown]
# ## Executive Summary
#
# ### 2017 Data Import & Cleaning
#
# Errors such as extra characters were corrected and percentages were removed to convert all numerical data in numbers with decimal points.
#
# ### 2018 Data Import and Cleaning
#
# Data was found to match the data fields of 2017's data. The cleaned-up data from both 2017 and 2018 were combined to a single data frame for the ease of comparison.
#
# ### Exploratory Data Analysis
#
# The standard deviation for each numerical variable were calculated using three different methods. The highest and lowest states were identified in terms of participation rates and scores.
#
# ### Data Visualization
#
# Histograms, box plots, heat maps and scatter plots were used to investigate the data and correlations further.
#
# ### Descriptive and Inferential Statistics
#
# Most of the statistics have a close-to-normal distribution. Although the data points add up to more than 30, more data points would further ensure a closer-to-normal distribution for the numerical variables used in this report.
#
# ### Outside Research
#
# Research has been undertaken from the official State Education Departments and other related articles. Some of these include the details of state policies with regards to the compulsory taking of the exams and/or the sponsoring of test fees.
#
# ### Conclusions and Recommendations
#
# State departments of education play a pivotal role in increasing the test participation rates. This can come in the form of state subsidies for the test or making the taking of the test mandatory for all school students. The states of West Virgina, Ohio, Rhode Island and Illinois are examples of such policies which greatly impacted SAT participation rates. The SAT Test Day, which happens on a regular school day also contributed to an increase in the overall SAT participation rate.
#
# Focus on collaboration with state education departments, colleges and high schools would likely lead to the continued increase in SAT participation rates.
#
# More research can be done on university admissions criteria in the U.S, SAT test centers and their usage to helps understand how to further drive participation rates.
#
# ### Contents:
# - [2017 Data Import & Cleaning](#2017-Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# # Data Dictionary
#
# | Feature                                    | Type     | Dataset | Description                                                  |
# | ------------------------------------------ | -------- | ------- | ------------------------------------------------------------ |
# | **state**                                  | *string* | ACT/SAT | The state in the United States of America.                   |
# | **sat_participation or act_participation** | *float*  | ACT/SAT | The percentage expressed as a float on the number of students enrolled in schools |
# | **sat_reading_and_writing**                | *float*  | SAT     | The average English reading and writing score in a maximum score of 800. |
# | **sat_math**                               | *float*  | SAT     | The average math score in a maximum score of 800.            |
# | **sat_total**                              | *float*  | SAT     | The combined score of sat_reading_and_writing and sat_math.  |
# | **act_english**                            | *float*  | ACT     | The average math score in a maximum score of 36.             |
# | **act_math**                               | *float*  | ACT     | The average math score in a maximum score of 36.             |
# | **act_reading**                            | *float*  | ACT     | The average reading score in a maximum score of 36.          |
# | **act_science**                            | *float*  | ACT     | The average science score in a maximum score of 36.          |
# | **act_composite**                          | *float*  | ACT     | The average score calculated by the 4 ACT scores of each state. |

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:

act_2017 = pd.read_csv('data/act_2017.csv')

# %%
sat_2017 = pd.read_csv('data/sat_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
sat_2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
act_2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer:
# Data is indexed by national results followed by states in alphabetical order.
# The SAT has two major categories, whereas the ACT has for categories to it.
# The SAT totals its scores, the ACT creates a composite score.

# %% [markdown]
# #### 4a. Does the data look complete?

# %%
#https://chartio.com/resources/tutorials/how-to-check-if-any-value-is-nan-in-a-pandas-dataframe/
sat_2017.isnull().values.any()
# Out:
# False

# %%
act_2017.isnull().values.any()
# Out:
# False

# %% [markdown]
# Answer: The data in both dataframes is complete.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer:

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#code
#https://www.geeksforgeeks.org/data-type-object-dtype-numpy-python/
#checking data types
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %%
act_2017.head(10)
#the participation column is a string and has a percentage symbol I want to remove
#from previewing the data I don't think I can convert the participation column without a function, but I looked ahead and that will be my answer to question 6
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
#https://datatofish.com/convert-string-to-float-dataframe/
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_numeric.html
#Composite column is a string and I want it as a float
act_2017['Composite'].value_counts()
# Out:
# 20.3     3
# 19.8     3
# 21.4     3
# 21.8     2
# 20.4     2
# 24.1     2
# 24.2     2
# 19.7     2
# 19.4     2
# 23.6     2
# 21.9     2
# 24.3     1
# 25.2     1
# 19.2     1
# 20.7     1
# 20.8     1
# 25.4     1
# 20.2x    1
# 22.6     1
# 22.0     1
# 25.5     1
# 19.0     1
# 18.6     1
# 19.1     1
# 21.5     1
# 17.8     1
# 22.8     1
# 24.0     1
# 21.0     1
# 22.3     1
# 23.8     1
# 23.9     1
# 19.5     1
# 20.0     1
# 18.7     1
# 23.7     1
# 20.5     1
# 21.7     1
# Name: Composite, dtype: int64

# %%
#from the previous cell error I am looking for a value 20.2x in the column Composite which is not a float b/c it has an x
act_2017['Composite'] == '20.2x'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51     True
# Name: Composite, dtype: bool

# %%
#I am going to look at the row of the error
act_2017.iloc[[51]]
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 51  Wyoming          100%     19.4  19.8     20.8     20.6     20.2x

# %%
#I have to calculate the composite score for myself
#I replace the cell with the error with the correct composite score
act_2017.iloc[51,6] = (act_2017.iloc[51][2] + act_2017.iloc[51][3] + act_2017.iloc[51][4] + act_2017.iloc[51][5])/4

#I check the error row once more
act_2017.iloc[[51]]
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 51  Wyoming          100%     19.4  19.8     20.8     20.6     20.15

# %%
#https://stackoverflow.com/questions/30095172/difference-between-str-and-astypestr
# I run this line again to make sure everything has been converted to floats
act_2017['Composite'] = act_2017['Composite'].astype(float)

# %%
#https://www.geeksforgeeks.org/data-type-object-dtype-numpy-python/
#check to see if the conversion to float worked
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
#https://www.geeksforgeeks.org/data-type-object-dtype-numpy-python/
#checking data types
#participation has the same problem, I will fix for problem 6
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#https://www.geeksforgeeks.org/data-type-object-dtype-numpy-python/
#code
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
#code
sat_2017.head(10)
#the SAT participation column has the same problem as the act, I need to remove percent and make into a float, I will address this in the next question
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# ### Answer:
# From answer to number file there were multiple columns which were supposed to be intergers or floats instead of objects, but I seem to have resolved them for the Composite Column on the ACT dataframe, however, the Participation column needs to have the percent character stripped from its numbers then needs for its numbers to be converted  floats. I need to do the same for the Participation column of the SAT dataframe

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
#code
#remove percentage and convert to float
#https://www.programiz.com/python-programming/methods/string/strip
#GA DSI Lesson 2.04
def rmv_pct(string):
        return float(string.strip('%'))/100

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
#code
#https://www.programiz.com/python-programming/methods/built-in/map
#convert participation to float for act
act_2017['Participation'] = act_2017['Participation'].map(rmv_pct)

# %%
#https://www.geeksforgeeks.org/data-type-object-dtype-numpy-python/
#check datatypes to see if the code worked
act_2017.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
#code
#https://www.programiz.com/python-programming/methods/built-in/map
#convert participation to float for sat
sat_2017['Participation'] = sat_2017['Participation'].map(rmv_pct)

# %%
#https://www.geeksforgeeks.org/data-type-object-dtype-numpy-python/
#accidental error for running code twice on block before this
#check again if participation is now in floats
sat_2017.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
#https://stackoverflow.com/questions/30095172/difference-between-str-and-astypestr
#I decided to just make all numerical columns into floats, although integers would have been ok
sat_2017['Evidence-Based Reading and Writing'] = sat_2017['Evidence-Based Reading and Writing'].astype(float)
sat_2017['Math'] = sat_2017['Math'].astype(float)
sat_2017['Total'] = sat_2017['Total'].astype(float)

# %%
#https://www.geeksforgeeks.org/data-type-object-dtype-numpy-python/
#I check my datatypes again
sat_2017.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing    float64
# Math                                  float64
# Total                                 float64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#previow data 
sat_2017.head(2)
# Out:
#      State  Participation  Evidence-Based Reading and Writing   Math   Total
# 0  Alabama           0.05                               593.0  572.0  1165.0
# 1   Alaska           0.38                               547.0  533.0  1080.0

# %%
#GA DSI Lesson 2.04
# Create dictionay of new column names for sat

sat_new_columns_dict = {
    'State' : 'state',
    'Participation' : 'sat_participation',
    'Evidence-Based Reading and Writing' : 'sat_reading_and_writing',
    'Math' : 'sat_math',
    'Total' : 'sat_total',
    
}

# %%
#https://note.nkmk.me/en/python-pandas-dataframe-rename/
#apply function
sat_2017.rename(columns = sat_new_columns_dict, inplace = True)

# %%
#preview data again
sat_2017.head(2)
# Out:
#      state  sat_participation  sat_reading_and_writing  sat_math  sat_total
# 0  Alabama               0.05                    593.0     572.0     1165.0
# 1   Alaska               0.38                    547.0     533.0     1080.0

# %%
#preview ACT data
act_2017.head(2)
# Out:
#       State  Participation  English  Math  Reading  Science  Composite
# 0  National            0.6     20.3  20.7     21.4     21.0       21.0
# 1   Alabama            1.0     18.9  18.4     19.7     19.4       19.2

# %%
#create act dictionary of new column names for act

act_new_columns_dic = {
    'State' : 'state',
    'Participation' : 'act_participation',
    'English' : 'act_english',
    'Math' : 'act_math',
    'Reading' : 'act_reading',
    'Science' : 'act_science',
    'Composite' : 'act_composite',
}

# %%
#https://note.nkmk.me/en/python-pandas-dataframe-rename/
#apply function
act_2017.rename(columns = act_new_columns_dic, inplace = True)

# %%
#preview data again
act_2017.head(2)
# Out:
#       state  act_participation  act_english  act_math  act_reading  \
# 0  National                0.6         20.3      20.7         21.4
# 1   Alabama                1.0         18.9      18.4         19.7
#
#    act_science  act_composite
# 0         21.0           21.0
# 1         19.4           19.2

# %% [markdown]
# #### 8. Create a data dictionary

# %% [markdown]
# | Feature                                    | Type     | Dataset | Description                                                  |
# | ------------------------------------------ | -------- | ------- | ------------------------------------------------------------ |
# | **state**                                  | *string* | ACT/SAT | The state in the United States of America.                   |
# | **sat_participation or act_participation** | *float*  | ACT/SAT | The percentage expressed as a float on the number of students enrolled in schools |
# | **sat_reading_and_writing**                | *float*  | SAT     | The average English reading and writing score in a maximum score of 800. |
# | **sat_math**                               | *float*  | SAT     | The average math score in a maximum score of 800.            |
# | **sat_total**                              | *float*  | SAT     | The combined score of sat_reading_and_writing and sat_math.  |
# | **act_english**                            | *float*  | ACT     | The average math score in a maximum score of 36.             |
# | **act_math**                               | *float*  | ACT     | The average math score in a maximum score of 36.             |
# | **act_reading**                            | *float*  | ACT     | The average reading score in a maximum score of 36.          |
# | **act_science**                            | *float*  | ACT     | The average science score in a maximum score of 36.          |
# | **act_composite**                          | *float*  | ACT     | The average score calculated by the 4 ACT scores of each state. |

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
#https://cmdlinetips.com/2018/04/how-to-drop-one-or-more-columns-in-pandas-dataframe/
#remove National row
act_2017.drop(0,axis = 0, inplace = True)

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Code:
#merge dataframes
merged_2017 = pd.merge(act_2017, sat_2017, on='state')

# %%
#preview new dataframe
merged_2017.head()
# Out:
#         state  act_participation  act_english  act_math  act_reading  \
# 0     Alabama               1.00         18.9      18.4         19.7
# 1      Alaska               0.65         18.7      19.8         20.4
# 2     Arizona               0.62         18.6      19.8         20.1
# 3    Arkansas               1.00         18.9      19.0         19.7
# 4  California               0.31         22.5      22.7         23.1
#
#    act_science  act_composite  sat_participation  sat_reading_and_writing  \
# 0         19.4           19.2               0.05                    593.0
# 1         19.9           19.8               0.38                    547.0
# 2         19.8           19.7               0.30                    563.0
# 3         19.5           19.4               0.03                    614.0
# 4         22.2           22.8               0.53                    531.0
#
#    sat_math  sat_total
# 0     572.0     1165.0
# 1     533.0     1080.0
# 2     553.0     1116.0
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code
#save cleaned merged dataframe
merged_2017.to_csv(r'./combined_2017.csv')

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Read in the `sat_2018.csv` and `act_2018.csv` files and assign them to appropriately named pandas dataframes. For the **2018 ACT Data**, only the `Composite` scores are available. Repeat the same processes to clean the 2018 data here as you were instructed in the previous sections above.

# %%
#read in dataframes
sat_2018 = pd.read_csv('data/sat_2018.csv')
act_2018 = pd.read_csv('data/act_2018.csv')

# %%
#https://www.geeksforgeeks.org/data-type-object-dtype-numpy-python/
sat_2018.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
sat_2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
#https://stackoverflow.com/questions/30095172/difference-between-str-and-astypestr
#I decided to just make all numerical columns into floats, although integers would have been ok
sat_2018['Evidence-Based Reading and Writing'] = sat_2018['Evidence-Based Reading and Writing'].astype(float)
sat_2018['Math'] = sat_2018['Math'].astype(float)
sat_2018['Total'] = sat_2018['Total'].astype(float)

# %%
#https://note.nkmk.me/en/python-pandas-dataframe-rename/
#rename columns using predefined function and dictionary
sat_2018.rename(columns = sat_new_columns_dict, inplace = True)

# %%
#https://www.programiz.com/python-programming/methods/built-in/map
#remove percent on participation column and turn into floats
sat_2018['sat_participation'] = sat_2018['sat_participation'].map(rmv_pct)

# %%
#preview data again
sat_2018.head()
# Out:
#         state  sat_participation  sat_reading_and_writing  sat_math  sat_total
# 0     Alabama               0.06                    595.0     571.0     1166.0
# 1      Alaska               0.43                    562.0     544.0     1106.0
# 2     Arizona               0.29                    577.0     572.0     1149.0
# 3    Arkansas               0.05                    592.0     576.0     1169.0
# 4  California               0.60                    540.0     536.0     1076.0

# %%
#https://www.geeksforgeeks.org/data-type-object-dtype-numpy-python/
act_2018.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
act_2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
#define new column dicitionary
act_new_2018_columns = {
    'State' : 'state',
    'Participation' : 'act_participation',
    'Composite' : 'act_composite',
}

# %%
#https://note.nkmk.me/en/python-pandas-dataframe-rename/
#rename columns using predefined function and dictionary
act_2018.rename(columns = act_new_2018_columns, inplace = True)

# %%
#https://www.programiz.com/python-programming/methods/built-in/map
#remove percent on participation column and turn into floats
act_2018['act_participation'] = act_2018['act_participation'].map(rmv_pct)

# %%
#preview data again
act_2018.head()
# Out:
#         state  act_participation  act_composite
# 0     Alabama               1.00           19.1
# 1      Alaska               0.33           20.8
# 2     Arizona               0.66           19.2
# 3    Arkansas               1.00           19.4
# 4  California               0.27           22.7

# %%
#combine sat and act 2018

merged_2018 = pd.merge(act_2018, sat_2018, on = 'state')

# %%
#preview merged dataframe
merged_2018.head()
# Out:
#         state  act_participation  act_composite  sat_participation  \
# 0     Alabama               1.00           19.1               0.06
# 1      Alaska               0.33           20.8               0.43
# 2     Arizona               0.66           19.2               0.29
# 3    Arkansas               1.00           19.4               0.05
# 4  California               0.27           22.7               0.60
#
#    sat_reading_and_writing  sat_math  sat_total
# 0                    595.0     571.0     1166.0
# 1                    562.0     544.0     1106.0
# 2                    577.0     572.0     1149.0
# 3                    592.0     576.0     1169.0
# 4                    540.0     536.0     1076.0

# %%
#save cleaned merged dataframe
merged_2018.to_csv(r'./combined_2018.csv')

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
#look at merged_2017 df
merged_2017.head()
# Out:
#         state  act_participation  act_english  act_math  act_reading  \
# 0     Alabama               1.00         18.9      18.4         19.7
# 1      Alaska               0.65         18.7      19.8         20.4
# 2     Arizona               0.62         18.6      19.8         20.1
# 3    Arkansas               1.00         18.9      19.0         19.7
# 4  California               0.31         22.5      22.7         23.1
#
#    act_science  act_composite  sat_participation  sat_reading_and_writing  \
# 0         19.4           19.2               0.05                    593.0
# 1         19.9           19.8               0.38                    547.0
# 2         19.8           19.7               0.30                    563.0
# 3         19.5           19.4               0.03                    614.0
# 4         22.2           22.8               0.53                    531.0
#
#    sat_math  sat_total
# 0     572.0     1165.0
# 1     533.0     1080.0
# 2     553.0     1116.0
# ...

# %%
df_2017_columns_dic = {
    'state' : 'state',
    'act_participation' : 'act_participation_2017',
    'act_english' : 'act_english_2017',
    'act_math' : 'act_math_2017',
    'act_reading' : 'act_reading_2017',
    'act_science' : 'act_science_2017',
    'act_composite' : 'act_composite_2017',
    'sat_participation' : 'sat_participation_2017',
    'sat_reading_and_writing' : 'sat_reading_and_writing_2017',
    'sat_math' : 'sat_math_2017',
    'sat_total' : 'sat_total_2017',
}

# %%
#https://note.nkmk.me/en/python-pandas-dataframe-rename/
merged_2017.rename(columns = df_2017_columns_dic, inplace = True)

# %%
merged_2017.head()
# Out:
#         state  act_participation_2017  act_english_2017  act_math_2017  \
# 0     Alabama                    1.00              18.9           18.4
# 1      Alaska                    0.65              18.7           19.8
# 2     Arizona                    0.62              18.6           19.8
# 3    Arkansas                    1.00              18.9           19.0
# 4  California                    0.31              22.5           22.7
#
#    act_reading_2017  act_science_2017  act_composite_2017  \
# 0              19.7              19.4                19.2
# 1              20.4              19.9                19.8
# 2              20.1              19.8                19.7
# 3              19.7              19.5                19.4
# 4              23.1              22.2                22.8
#
#    sat_participation_2017  sat_reading_and_writing_2017  sat_math_2017  \
# 0                    0.05                         593.0          572.0
# ...

# %%
#look at merged_2018 df
merged_2018.head()
# Out:
#         state  act_participation  act_composite  sat_participation  \
# 0     Alabama               1.00           19.1               0.06
# 1      Alaska               0.33           20.8               0.43
# 2     Arizona               0.66           19.2               0.29
# 3    Arkansas               1.00           19.4               0.05
# 4  California               0.27           22.7               0.60
#
#    sat_reading_and_writing  sat_math  sat_total
# 0                    595.0     571.0     1166.0
# 1                    562.0     544.0     1106.0
# 2                    577.0     572.0     1149.0
# 3                    592.0     576.0     1169.0
# 4                    540.0     536.0     1076.0

# %%
df_2018_columns_dic = {
    'state' : 'state',
    'act_participation' : 'act_participation_2018',
    'act_composite' : 'act_composite_2018',
    'sat_participation' : 'sat_participation_2018',
    'sat_reading_and_writing' : 'sat_reading_and_writing_2018',
    'sat_math' : 'sat_math_2018',
    'sat_total' : 'sat_total_2018',
}

# %%
#https://note.nkmk.me/en/python-pandas-dataframe-rename/
merged_2018.rename(columns = df_2018_columns_dic, inplace = True)

# %%
merged_2018.head()
# Out:
#         state  act_participation_2018  act_composite_2018  \
# 0     Alabama                    1.00                19.1
# 1      Alaska                    0.33                20.8
# 2     Arizona                    0.66                19.2
# 3    Arkansas                    1.00                19.4
# 4  California                    0.27                22.7
#
#    sat_participation_2018  sat_reading_and_writing_2018  sat_math_2018  \
# 0                    0.06                         595.0          571.0
# 1                    0.43                         562.0          544.0
# 2                    0.29                         577.0          572.0
# 3                    0.05                         592.0          576.0
# 4                    0.60                         540.0          536.0
#
#    sat_total_2018
# 0          1166.0
# 1          1106.0
# 2          1149.0
# 3          1169.0
# 4          1076.0

# %%
final = pd.merge(merged_2017, merged_2018, on='state')

# %%
final.to_csv(r'./final.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
final.head()
# Out:
#         state  act_participation_2017  act_english_2017  act_math_2017  \
# 0     Alabama                    1.00              18.9           18.4
# 1      Alaska                    0.65              18.7           19.8
# 2     Arizona                    0.62              18.6           19.8
# 3    Arkansas                    1.00              18.9           19.0
# 4  California                    0.31              22.5           22.7
#
#    act_reading_2017  act_science_2017  act_composite_2017  \
# 0              19.7              19.4                19.2
# 1              20.4              19.9                19.8
# 2              20.1              19.8                19.7
# 3              19.7              19.5                19.4
# 4              23.1              22.2                22.8
#
#    sat_participation_2017  sat_reading_and_writing_2017  sat_math_2017  \
# 0                    0.05                         593.0          572.0
# ...

# %%
#https://note.nkmk.me/en/python-pandas-dataframe-rename/
#I made a mistake and didn't type in act_composite into the dictionary with its year
final.rename(columns={final.columns[12]:'act_composite_2018'}, inplace=True)

# %%
#all fixed
final.head()
# Out:
#         state  act_participation_2017  act_english_2017  act_math_2017  \
# 0     Alabama                    1.00              18.9           18.4
# 1      Alaska                    0.65              18.7           19.8
# 2     Arizona                    0.62              18.6           19.8
# 3    Arkansas                    1.00              18.9           19.0
# 4  California                    0.31              22.5           22.7
#
#    act_reading_2017  act_science_2017  act_composite_2017  \
# 0              19.7              19.4                19.2
# 1              20.4              19.9                19.8
# 2              20.1              19.8                19.7
# 3              19.7              19.5                19.4
# 4              23.1              22.2                22.8
#
#    sat_participation_2017  sat_reading_and_writing_2017  sat_math_2017  \
# 0                    0.05                         593.0          572.0
# ...

# %%
l = final.describe()
l.T
# Out:
#                               count         mean        std     min       25%  \
# act_participation_2017         51.0     0.647843   0.328063    0.08     0.310
# act_english_2017               51.0    20.927451   2.347942   16.30    19.000
# act_math_2017                  51.0    21.192157   1.994878   18.00    19.400
# act_reading_2017               51.0    22.011765   2.064524   18.10    20.450
# act_science_2017               51.0    21.045098   3.185675    2.30    19.900
# act_composite_2017             51.0    21.520588   2.024060   17.80    19.800
# sat_participation_2017         51.0     0.397059   0.351126    0.02     0.040
# sat_reading_and_writing_2017   51.0   569.725490  44.679784  503.00   533.500
# sat_math_2017                  51.0   548.235294  84.437335   52.00   522.000
# sat_total_2017                 51.0  1127.313725  90.520382  996.00  1055.500
# act_participation_2018         51.0     0.612353   0.346483    0.07     0.270
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#code
#function created with help from https://www.w3resource.com/python-exercises/math/python-math-exercise-57.php
def std_dev(values):
    
    n = len(values)
    mean = sum(values) / n
    x = 0
    
    for i in values:
        x += (i - mean)**2
        var = x / n
        std = var ** 0.5
        
    return std

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
#Code:

#taking out the state column
df = final[final.columns[1:21]]

#getting standard devation using dictionary comprehension
sd = {k: std_dev(df[k]) for k in df.columns}

# %%
#preview dictionary
sd
# Out:
# {'act_participation_2017': 0.32483065709110037,
#  'act_english_2017': 2.324808946936057,
#  'act_math_2017': 1.9752233070336587,
#  'act_reading_2017': 2.0441832405895677,
#  'act_science_2017': 3.154288318196337,
#  'act_composite_2017': 2.004117733386279,
#  'sat_participation_2017': 0.34766613530488066,
#  'sat_reading_and_writing_2017': 44.23957878011567,
#  'sat_math_2017': 83.60541971251418,
#  'sat_total_2017': 89.62853410235164,
#  'act_participation_2018': 0.343069124889043,
#  'act_composite_2018': 2.099389340187203,
#  'sat_participation_2018': 0.3713074253933647,
#  'sat_reading_and_writing_2018': 46.66211050422986,
#  'sat_math_2018': 46.724399944493776,
#  'sat_total_2018': 92.273268159942}

# %%
np.std(final)
# Out:
# act_participation_2017           0.324831
# act_english_2017                 2.324809
# act_math_2017                    1.975223
# act_reading_2017                 2.044183
# act_science_2017                 3.154288
# act_composite_2017               2.004118
# sat_participation_2017           0.347666
# sat_reading_and_writing_2017    44.239579
# sat_math_2017                   83.605420
# sat_total_2017                  89.628534
# act_participation_2018           0.343069
# act_composite_2018               2.099389
# sat_participation_2018           0.371307
# sat_reading_and_writing_2018    46.662111
# sat_math_2018                   46.724400
# sat_total_2018                  92.273268
# dtype: float64

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# ### Answer
# My calculated standard deviations values are close to numpy's std method. The output from pandas describe has a slightly larger difference but is still very close. This is might be due to the default delta degrees of freedom.

# %% [markdown]
# #### Investigate trends in the data
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
#
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
#
# - Do any states with 100% participation on a given test have a rate change year-to-year?
#
# - Do any states show have >50% participation on *both* tests either year?

# %%
#masking to show states that have more than 50% participation in both tests in 2017
a = final[['state','sat_participation_2017','act_participation_2017']]

a[(a['sat_participation_2017'] > 0.5) & (a.act_participation_2017 > 0.5)].reset_index(drop = True)
# Out:
#      state  sat_participation_2017  act_participation_2017
# 0  Florida                    0.83                    0.73
# 1  Georgia                    0.61                    0.55
# 2   Hawaii                    0.55                    0.90

# %% [markdown]
# Hawaii has the highest ACT participation percentage in 2017.
# Florida has the highest SAT participation percentage in 2017.

# %%
#masking to show states that have more than 50% participation in both tests in 2018
b = final[['state','sat_participation_2018','act_participation_2018']]

b[(b['sat_participation_2018'] > 0.5) & (b.act_participation_2018> 0.5)].reset_index(drop = True)
# Out:
#             state  sat_participation_2018  act_participation_2018
# 0         Florida                    0.56                    0.66
# 1         Georgia                    0.70                    0.53
# 2          Hawaii                    0.56                    0.89
# 3  North Carolina                    0.52                    1.00
# 4  South Carolina                    0.55                    1.00

# %% [markdown]
# Both North Carolina and South Carolina have 100% test participation for the ACT in 2018.
# Georgia had the highest SAT participation percentage in 2018 at 70%.

# %%
#showing only the state and sat_participation_2017 columns
sat_participation_2017 = final.loc[:,['state','sat_participation_2017']]

#putting the top 5 and bottom 5 states in one DataFrame
sat_participation_2017.sort_values(by = ['sat_participation_2017'], 
                                   ascending=False).head().append(sat_participation_2017.sort_values(by=['sat_participation_2017'], 
                                   ascending=False).tail()).reset_index(drop = True)
# Out:
#            state  sat_participation_2017
# 0       Delaware                    1.00
# 1       Michigan                    1.00
# 2    Connecticut                    1.00
# 3  New Hampshire                    0.96
# 4          Maine                    0.95
# 5       Arkansas                    0.03
# 6        Wyoming                    0.03
# 7   North Dakota                    0.02
# 8    Mississippi                    0.02
# 9           Iowa                    0.02

# %% [markdown]
# Delaware, Michigan, and Connecticut had 100% SAT participation in 2017.
# North Dakota, Mississippi, and Iowa had the lowest SAT participation in 2017 at 2%.

# %%
#showing only the state and sat_participation_2018 columns
sat_participation_2018 = final.loc[:,['state','sat_participation_2018']]
#putting the top 5 and bottom 5 states in one DataFrame
sat_participation_2018.sort_values(by = ['sat_participation_2018'], 
                                   ascending=False).head().append(sat_participation_2018.sort_values(by=['sat_participation_2018'],
                                   ascending=False).tail()).reset_index(drop = True)
# Out:
#           state  sat_participation_2018
# 0      Colorado                    1.00
# 1   Connecticut                    1.00
# 2      Delaware                    1.00
# 3      Michigan                    1.00
# 4         Idaho                    1.00
# 5   Mississippi                    0.03
# 6          Iowa                    0.03
# 7     Wisconsin                    0.03
# 8       Wyoming                    0.03
# 9  North Dakota                    0.02

# %% [markdown]
# Colorado, Connecticut, Delaware, Michigan, and Idaho had 100% SAT participation in 2018.
# North Dakota had the lowest participation at 2%.

# %%
#showing only the state and act_participation_2017 columns
act_participation_2017 = final.loc[:,['state','act_participation_2017']]

#putting the top 5 and bottom 5 states in one DataFrame
act_participation_2017.sort_values(by = ['act_participation_2017'], 
                                   ascending=False).head().append(act_participation_2017.sort_values(by=['act_participation_2017'], 
                                   ascending=False).tail()).reset_index(drop = True)
# Out:
#            state  act_participation_2017
# 0        Alabama                    1.00
# 1       Kentucky                    1.00
# 2      Wisconsin                    1.00
# 3           Utah                    1.00
# 4      Tennessee                    1.00
# 5   Rhode Island                    0.21
# 6       Delaware                    0.18
# 7  New Hampshire                    0.18
# 8          Maine                    0.08
# 9          Maine                    0.08

# %% [markdown]
# Alabama, Kentucky, Wisconson, Utah, and Tennessee had the had the highest ACT participation in 2017 at 100%.
# Maine had the lowest at 8%. Not sure why it shows up twice in my filter.

# %%
#showing only the state and act_participation_2018 columns
act_participation_2018 = final.loc[:,['state','act_participation_2018']]

#putting the top 5 and bottom 5 states in one DataFrame
act_participation_2018.sort_values(by = ['act_participation_2018'], 
                                   ascending=False).head().append(act_participation_2018.sort_values(by=['act_participation_2018'], 
                                   ascending=False).tail()).reset_index(drop = True)
# Out:
#            state  act_participation_2018
# 0        Alabama                    1.00
# 1       Kentucky                    1.00
# 2      Wisconsin                    1.00
# 3           Utah                    1.00
# 4      Tennessee                    1.00
# 5       Delaware                    0.17
# 6  New Hampshire                    0.16
# 7   Rhode Island                    0.15
# 8          Maine                    0.07
# 9          Maine                    0.07

# %% [markdown]
# Alabama, Kentucky, Wisconson, Utah, and Tennessee had the had the highest ACT participation in 2018 at 100%.
# Maine had the lowest at 7%. Not sure why it shows up twice in my filter.

# %%
#showing only the state and sat_total_2017 columns
sat_total_2017 = final.loc[:,['state','sat_total_2017']]

#putting the top 5 and bottom 5 states in one DataFrame
sat_total_2017.sort_values(by = ['sat_total_2017'],
                           ascending=False).head().append(sat_total_2017.sort_values(by=['sat_total_2017'], 
                           ascending=False).tail()).reset_index(drop = True)
# Out:
#        state  sat_total_2017
# 0  Minnesota          1295.0
# 1  Wisconsin          1291.0
# 2       Iowa          1275.0
# 3   Missouri          1271.0
# 4     Kansas          1260.0
# 5      Maine          1012.0
# 6      Maine          1012.0
# 7   Michigan          1005.0
# 8      Idaho          1005.0
# 9   Delaware           996.0

# %% [markdown]
# Minnesota scored the highest on the SAT in 2017, Delaware scored the lowest.

# %%
#showing only the state and sat_total2018 columns
sat_total_2018 = final.loc[:,['state','sat_total_2018']]

#putting the top 5 and bottom 5 states in one DataFrame
sat_total_2018.sort_values(by = ['sat_total_2018'], 
                           ascending=False).head().append(sat_total_2018.sort_values(by=['sat_total_2018'], 
                           ascending=False).tail()).reset_index(drop = True)
# Out:
#            state  sat_total_2018
# 0      Minnesota          1298.0
# 1      Wisconsin          1294.0
# 2   North Dakota          1283.0
# 3           Iowa          1265.0
# 4         Kansas          1265.0
# 5           Utah          1010.0
# 6         Hawaii          1010.0
# 7          Idaho          1001.0
# 8  West Virginia           999.0
# 9       Delaware           998.0

# %% [markdown]
# Minnesota scored the highest on the SAT in 2018, Delaware scored the lowest.

# %%
#showing only the state and act_composite_2017 columns
act_composite_2017 = final.loc[:,['state','act_composite_2017']]

#putting the top 5 and bottom 5 states in one DataFrame
act_composite_2017.sort_values(by=['act_composite_2017'], 
                               ascending=False).head().append(act_composite_2017.sort_values(by=['act_composite_2017'], 
                               ascending=False).tail()).reset_index(drop = True)
# Out:
#             state  act_composite_2017
# 0   New Hampshire                25.5
# 1   Massachusetts                25.4
# 2     Connecticut                25.2
# 3           Maine                24.3
# 4           Maine                24.3
# 5  North Carolina                19.1
# 6          Hawaii                19.0
# 7  South Carolina                18.7
# 8     Mississippi                18.6
# 9          Nevada                17.8

# %% [markdown]
# New Hampshire scored the highest on the ACT in 2017, Nevada scored the lowest.

# %%
#showing only the state and act_composite_2018 columns
act_composite_2018 = final.loc[:,['state','act_composite_2018']]

#putting the top 5 and bottom 5 states in one DataFrame
act_composite_2018.sort_values(by = ['act_composite_2018'], 
                               ascending=False).head().append(act_composite_2018.sort_values(by=['act_composite_2018'], 
                               ascending=False).tail()).reset_index(drop = True)
# Out:
#             state  act_composite_2018
# 0     Connecticut                25.6
# 1   Massachusetts                25.5
# 2   New Hampshire                25.1
# 3        New York                24.5
# 4    Rhode Island                24.2
# 5         Alabama                19.1
# 6          Hawaii                18.9
# 7     Mississippi                18.6
# 8  South Carolina                18.3
# 9          Nevada                17.7

# %% [markdown]
# Connecticut scored the highest on the ACT in 2018, Nevada scored the lowest.

# %% [markdown]
# ## Data Visualization

# %%
#GA DSI Lesson 2.04
#created a heatmap of test correlations
import seaborn as sns
sns.set(font_scale=1.1)
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12,10)) 
sns.heatmap(final.corr(), cmap = 'Blues',annot = True )
plt.title('Aptitude Test Correlations', fontsize = '35', pad = '20');

# %% [markdown]
# #### Custom function to subplot histograms

# %%
#function created with help from Codecademy Data Science Path Data and Visualization Section
#also help from https://stackoverflow.com/questions/20174468/how-to-create-subplots-of-pictures-made-with-the-hist-function-in-matplotlib-p

def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    
    #https://matplotlib.org/2.0.0/examples/color/named_colors.html
    
    colors = ['darkcyan', 'olive', 'indianred', 'rebeccapurple']
    nrows = int(np.ceil(len(list_of_columns) / 2)) # Makes sure there are enough rows
    
    fig, ax = plt.subplots(nrows = nrows, ncols = 2,figsize = (16,16)) 
    ax = ax.ravel() # Ravel turns a matrix into a vector, making it easier to iterate
    
    fig.tight_layout(pad=6.5)
    
    for i, column in enumerate(list_of_columns): # Gives an index value to all lists
        ax[i].hist(dataframe[column], color = colors[i], alpha = 0.3) 
        # Set titles and labels for each subplot
        ax[i].set_title(list_of_titles[i],fontsize = 35)
        ax[i].set_xlabel(list_of_xlabels[i],fontsize = 20)
        ax[i].set_ylabel('Number of States',fontsize = 20)

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
#created with help from Codecademy Data Science Path Data and Visualization Section
list_of_columns = ['sat_participation_2017','sat_participation_2018',
                   'act_participation_2017','act_participation_2018']

list_of_titles = ['SAT 2017','SAT 2018','ACT 2017','ACT 2018']

list_of_xlabels = ['SAT Participation in 2017','SAT Participation in 2018',
                   'ACT Participationin 2017','ACT Participation in 2018']  

subplot_histograms(final, list_of_columns, list_of_titles, list_of_xlabels)

# %% [markdown]
# In 2017 and 2018 more than 17 states (the majority)  had less than 2 % participation in the SAT.
#
#
# In 2017 and 2018 more than 17 states (the majority)  had close to or 100 % participation in the ACT.

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
#
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018

# %%
#created with help from Codecademy Data Science Path Data and Visualization Section
ax = plt.subplots(figsize = (10,10))
ax = sns.regplot(y = 'sat_math_2017', x = 'act_math_2017', 
                 data = final[['sat_math_2017','act_math_2017']], color = 'blueviolet')
ax.set_title('SAT vs ACT Math Scores 2017',fontsize = 35)
ax.set_xlabel('ACT Math 2017',fontsize = 20)
ax.set_ylabel('SAT Math 2017',fontsize = 20);

# %% [markdown]
# The distribution of test scores from the states who participated from the SAT and ACT Math test compared to each other show that states did better on the SAT math than the ACT Math.
#
# Also, the trend line confirms this by its placement towards the top part of the chart.

# %%
#created with help from Codecademy Data Science Path Data and Visualization Section
ax = plt.subplots(figsize = (10,10))
ax = sns.regplot(y = 'sat_reading_and_writing_2017', x = 'act_reading_2017',
                 data=final[['sat_reading_and_writing_2017','act_reading_2017']], color = 'green')
ax.set_title('SAT vs ACT Verbal/Reading Scores',fontsize = 35)
ax.set_xlabel('ACT Reading 2017',fontsize = 20)
ax.set_ylabel('SAT Reading & Writing 2017',fontsize = 20);

# %% [markdown]
# The distribution of test scores from the states who participated from the SAT and ACT Verbal / Reading test compared to each other show that states did better on the ACT Verbal / Reading than the SAT Verbal / Reading.
#
# Also, the trend line negative slope confirms this trend by its heading to the bottom right of the chart.

# %%
#created with help from Codecademy Data Science Path Data and Visualization Section
ax = plt.subplots(figsize = (10,10))
ax = sns.regplot(y = 'sat_total_2017', x = 'act_composite_2017',
                 data = final[['sat_total_2017','act_composite_2017']], color = 'orange')
ax.set_title('SAT vs ACT Total/Composite Scores',fontsize = 35)
ax.set_xlabel('ACT Composite Score 2017',fontsize = 20)
ax.set_ylabel('SAT Total Score 2017',fontsize = 20);

# %% [markdown]
# The distribution of test scores from the states who participated from the SAT and ACT Composite test scores compared to each other show that states did better on the ACT  than the SAT.
#
# Also, the trend line negative slope confirms this trend by its heading to the bottom right of the chart.

# %%
#created with help from Codecademy Data Science Path Data and Visualization Section
ax = plt.subplots(figsize = (10,10))
ax = sns.regplot(y = 'sat_total_2017', x = 'sat_total_2018', 
                 data = final[['sat_total_2017','sat_total_2018']], color = 'darkcyan')
ax.set_title('SAT Total Score 2017 vs 2018',fontsize = 35)
ax.set_xlabel('SAT Total 2018',fontsize = 20)
ax.set_ylabel('SAT Total 2017',fontsize = 20)
# Out:
# Text(0, 0.5, 'SAT Total 2017')

# %% [markdown]
# The positive trend line of the two year’s scores from the states who participated compared against each other show that the scores seem to be consistent year to year.

# %%
#created with help from Codecademy Data Science Path Data and Visualization Section
ax = plt.subplots(figsize = (10,10))
ax = sns.regplot(y = 'act_composite_2017', x = 'act_composite_2018', 
                 data=final[['act_composite_2017','act_composite_2018']], color = 'darkgoldenrod')
ax.set_title('ACT Composite Score 2017 vs 2018',fontsize = 35)
ax.set_xlabel('ACT Composite 2018',fontsize = 20)
ax.set_ylabel('ACT Composite 2017',fontsize = 20);

# %% [markdown]
# The positive trend line of the two year’s scores from the states who participated compared against each other show that the scores seem to be consistent year to year.

# %% [markdown]
# #### Plot and interpret boxplots

# %%
# Code
#created with help from Codecademy Data Science Path Data and Visualization Section
x = plt.subplots(figsize = (15,10))
plt.title('SAT Scores',fontsize = 35)
plt.ylabel('Score', fontsize = 20, labelpad = 20)
plt.ylim(450, 675)
plt.xlabel('Subject Tests and Year', fontsize = 20, labelpad = 20)


sns.boxplot(data = final[['sat_reading_and_writing_2017','sat_reading_and_writing_2018',
                          'sat_math_2017','sat_math_2018']],  width = 0.8);

# %% [markdown]
# From the box plots, it can be seen that most of the scores from both tests in both years have a positive skew. Meaning that the lower scores are closer together than that of the higher scores.
#
# Also, the range of the scores seem to be consistent year to year.

# %%
#created with help from Codecademy Data Science Path Data and Visualization Section
ax = plt.subplots(figsize = (15,10))
plt.title('ACT Composite Scores',fontsize = 35)
plt.ylabel('Score',fontsize = 20, labelpad = 20)
plt.ylim(16, 27)
plt.xlabel('Composite Year', fontsize = 20, labelpad = 20)
sns.boxplot(data = final[['act_composite_2017','act_composite_2018']], width=0.7);

# %% [markdown]
# From the box plots, it can be seen that the composite scores both in years have a positive skew. Meaning that the lower scores are closer together than that of the higher scores.
#
# Also, the median and range of the scores seem to consistent year to year.

# %% [markdown]
# #### Additional tables and plots

# %%
#showing the biggest movements in SAT participation
sat_participation_change = pd.DataFrame(final,columns=['state','sat_participation_2018','sat_participation_2017'])

sat_participation_change['diff'] = sat_participation_change['sat_participation_2018'] - sat_participation_change['sat_participation_2017']

#putting the top 5 and bottom 5 states in one DataFrame
sat_participation_change.sort_values(['diff'],ascending=False).head().append(sat_participation_change.sort_values(['diff'],ascending=False).tail()).reset_index(drop = True)
# Out:
#            state  sat_participation_2018  sat_participation_2017  diff
# 0       Illinois                    0.99                    0.09  0.90
# 1       Colorado                    1.00                    0.11  0.89
# 2   Rhode Island                    0.97                    0.71  0.26
# 3  West Virginia                    0.28                    0.14  0.14
# 4       New York                    0.79                    0.67  0.12
# 5       Nebraska                    0.03                    0.03  0.00
# 6        Wyoming                    0.03                    0.03  0.00
# 7        Arizona                    0.29                    0.30 -0.01
# 8         Nevada                    0.23                    0.26 -0.03
# 9        Florida                    0.56                    0.83 -0.27

# %%
#showing the biggest movements in ACT participation
act_participation_change = pd.DataFrame(final,columns=['state','act_participation_2018','act_participation_2017'])

act_participation_change['diff'] = act_participation_change['act_participation_2018'] - act_participation_change['act_participation_2017']

#putting the top 5 and bottom 5 states in one DataFrame
act_participation_change.sort_values(['diff'],ascending=False).head().append(act_participation_change.sort_values(['diff'],ascending=False).tail()).reset_index(drop = True)
# Out:
#       state  act_participation_2018  act_participation_2017  diff
# 0      Ohio                    1.00                    0.75  0.25
# 1  Nebraska                    1.00                    0.84  0.16
# 2   Arizona                    0.66                    0.62  0.04
# 3  Maryland                    0.31                    0.28  0.03
# 4    Oregon                    0.42                    0.40  0.02
# 5   Florida                    0.66                    0.73 -0.07
# 6  Michigan                    0.22                    0.29 -0.07
# 7    Alaska                    0.33                    0.65 -0.32
# 8  Illinois                    0.43                    0.93 -0.50
# 9  Colorado                    0.30                    1.00 -0.70

# %% [markdown]
# ####  Tableau choropleth maps for test participation.

# %%
#https://stackoverflow.com/questions/11854847/how-can-i-display-an-image-from-a-file-in-jupyter-notebook
from IPython.display import Image

# %%
#https://www.tutorialgateway.org/how-to-create-a-map-in-tableau/
#https://www.youtube.com/watch?v=JBS15pL_e6Q
Image(filename = 'tableau_viz/act_participation_2017.png')

# %%
#https://www.tutorialgateway.org/how-to-create-a-map-in-tableau/
#https://www.youtube.com/watch?v=JBS15pL_e6Q
Image(filename = 'tableau_viz/act_participation_2018.png')

# %%
#https://www.tutorialgateway.org/how-to-create-a-map-in-tableau/
#https://www.youtube.com/watch?v=JBS15pL_e6Q
Image(filename = 'tableau_viz/sat_participation_2017.png')

# %%
#https://www.tutorialgateway.org/how-to-create-a-map-in-tableau/
#https://www.youtube.com/watch?v=JBS15pL_e6Q
Image(filename = 'tableau_viz/sat_participation_2018.png')

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# Colorado SAT. (n.d.). Retrieved July 30, 2020, from https://www.cde.state.co.us/assessment/coloradosat
#
# Genota, L. (2019, February 20). SAT Scores Rise as Number of Test-Takers Tops 2 Million. Retrieved July 30, 2020, from https://www.edweek.org/ew/articles/2018/10/31/sat-scores-rise-as-number-of-test-takers.html
#
# PSAT10 and SAT School Day. (n.d.). Retrieved July 30, 2020, from http://www.ride.ri.gov/InstructionAssessment/Assessment/PSATandSAT.aspx
#
# Rado, D. (2016, February 13). Illinois moves ahead with new testing plan, replacing ACT with SAT. Retrieved July 30, 2020, from https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html
#
# SAT School Day (High School). (n.d.). Retrieved July 30, 2020, from https://wvde.us/assessment/sat-school-day-high-school/
#
# State-Funded SAT Tests. (n.d.). Retrieved July 30, 2020, from http://education.ohio.gov/Topics/Testing/State-Funded-SAT-Test

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# ### Key Takeaways
# Based on the data, major movements in participation rates are spurred on by the state department of education's policies. If a state were to mandate a requirement for all students to take a particular test, the participation rate for the rate would increase exponentiallly. From further research, we also found that implementation of such policies are usually met on with high opposition from the competition.
#
# Ohio state law requires districts and community schools to administer the state-funded ACT or SAT to all grade 11 students. This has resulted in an increase for participation for both ACT and SAT tests.
#
# Rhode Island has made SAT testing compulsory for all students. This was implemented between 2017 and 2018 and its effects can be seen in the SAT participation, from 71% in 2017 to 97% in 2018.
#
# Illinois, like Rhode Island, has also made SAT testing compulsory for all public high school juniors. This has caused an exponential incrase in SAT participation from 9% to 99%. The ACT partipation rate was halved during this period. It should be noted that this move by the Illinois State Board of Education opposed this decision and is awaiting the final outcome.
#
# In West Virginia, the participation for SAT has doubled from 14% to 28% while ACT saw a decrease by 5%. This can be attributed to the education department's implementation of the SAT School Day where high school students can take the SAT tests on an allocated school day rather than taking in on a weekend and usually at a test center which they do not school at.
#
# Between 2017 and 2018, 10 states (Colorado, Connecticut, Delaware, Idaho, Illinois, Maine, Michigan, New Hampshire, Rhode Island, and West Virginia) and the District of Columbia covered the cost of the SAT for all their public school students. Three years ago, only three states and the District of Columbia did so. This, and the implementation of the SAT School Day contributed to the overall 25% increase in SAT test-takers.
#
# As such, the SAT School Day and the cost subsidy of the SAT can be seen to greatly improve SAT participation rates.
#
# ### Recommendations
# First its obvious that a states' department of education has the highest and most immediate impact on participation rates of a test. This would be in terms of a mandatory test in all schools within the state.
#
# It is also paramount to maintain the working relationships with the states already implementing mandatory tests in their location. This would come in the form of customer service, reliability and efficiency in administering the tests and getting the results.
#
# Success stories can also be seen in states where the education department subsidzes the full costs of the test, making them more accessible to lower income students.
#
# The college board should explore working with both high schools and colleges. A college's admission criteria based on either of the tests' score would have an huge impact on the perceived value of the test. The value to colleges of a single type of test for the admissions criteria is that they have a single metric which they can rank their applicants by, rather than having to compare their over two sets of metrics. Colleges have also been observed to be moving away from standardized tests. This issue should also be addressed to prove the need for these tests in providing impartial information about their applicants.
#
# Further research should be done on the university admissions criteria, the type of test and the scores students have been accepted upon and the composition of students taking both tests. Furthermore, information about the test centers and their usage could also shed some light on the matter. These would help to identify both tatical and strategic targets for College Board to further improve the SAT participation.

# %% [markdown]
# ## Bonus: Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions

# %%
l.T
# Out:
#                               count         mean        std     min       25%  \
# act_participation_2017         51.0     0.647843   0.328063    0.08     0.310
# act_english_2017               51.0    20.927451   2.347942   16.30    19.000
# act_math_2017                  51.0    21.192157   1.994878   18.00    19.400
# act_reading_2017               51.0    22.011765   2.064524   18.10    20.450
# act_science_2017               51.0    21.045098   3.185675    2.30    19.900
# act_composite_2017             51.0    21.520588   2.024060   17.80    19.800
# sat_participation_2017         51.0     0.397059   0.351126    0.02     0.040
# sat_reading_and_writing_2017   51.0   569.725490  44.679784  503.00   533.500
# sat_math_2017                  51.0   548.235294  84.437335   52.00   522.000
# sat_total_2017                 51.0  1127.313725  90.520382  996.00  1055.500
# act_participation_2018         51.0     0.612353   0.346483    0.07     0.270
# ...

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# ### Answer
# As the sample size is more than 30, there is tendency for the data to be normally distributed. However, some of the current data still show a positive skew. Should the sample size be larger, the distribution in comparison would be 'more normal'.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# ### Answer
# This assumption holds for the math and reading scores. The distributions for these two variables are close to normal.
#
# As for the participation rates, the assumption does not hold. This is largely due to state level policies which results in skewed distributions.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# ### Answer
# No it does not make sense to conduct statistical inference given these data. Although all 50 states are reflected in the data, more inferences can be drawn should there be more data points. Also, the participation rates do not reflect the actual number of students taking the tests. Minor changes in participation rates for certain states could actually result in a large increase in the overall number of test takers.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# ### Answer
# No it is not appropriate. The SAT (200-800) and ACT math (1-36) scores have very large differences in terms of the scale that they use.
